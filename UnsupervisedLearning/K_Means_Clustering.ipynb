# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
X,y = make_blobs(n_samples=1000, centers=3, n_features=2,random_state=23)

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=23)

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for k in range(1,11):
  kmeans=KMeans(n_clusters=k,init='k-means++')
  kmeans.fit(X_train)
  wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [35763.356599619714,
#  8297.202114173544,
#  1394.6687381999263,
#  1246.3866063619537,
#  1094.7671924502888,
#  974.1769674922883,
#  836.8020639249866,
#  725.0271449970875,
#  663.7214748910898,
#  579.2252528527407]

# %%
plt.plot(range(1,11),wcss)

# %%
y_label = kmeans.fit_predict(X_train)

# %%
plt.scatter(X_train[:,0],X_train[:,1],c=y_label)

# %%
from sklearn.metrics import silhouette_score

silhouette_coef=[]
for k in range(2,11):
  kmeans=KMeans(n_clusters=k,init='k-means++')
  kmeans.fit(X_train)
  score = silhouette_score(X_train,kmeans.labels_)
  silhouette_coef.append(score)

# %%
silhouette_coef
# Out:
# [np.float64(0.7252547694122655),
#  np.float64(0.8027214370116031),
#  np.float64(0.6435075557142425),
#  np.float64(0.47253124328109664),
#  np.float64(0.6187672154518224),
#  np.float64(0.5051811717970071),
#  np.float64(0.3406663790150623),
#  np.float64(0.34793128274773216),
#  np.float64(0.33594826524279614)]
